# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\tgandhi\\Desktop\\dataScience\\data\\sqrAnalysisData.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#    Metric Value - 4-Year Graduation Rate - Self-Contained, Integrated Co-Teaching, or SETSS  \
# 0                                              0.385
# 1                                              0.611
# 2                                              0.696
# 3                                              0.150
# 4                                              1.000
#
#    Metric Value - 4-Year Graduation Rate - English Language Learners  \
# 0                                              0.500
# 1                                              0.739
# 2                                              0.833
# 3                                              0.250
# 4                                                NaN
#
#    Metric Value - 4-Year Graduation Rate - Lowest Third Citywide  \
# 0                                              0.348
# ...
